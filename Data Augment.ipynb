# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator , load_img,img_to_array
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
pic=load_img('40_manual1.gif')

# %%
pic
# Out:
# <PIL.Image.Image image mode=RGB size=565x584 at 0x1ABEF57A2E0>

# %%
dg=ImageDataGenerator(horizontal_flip="True")

# %%
parray=img_to_array(pic)

# %%
parray.shape
# Out:
# (584, 565, 3)

# %%
parray=parray.reshape((1,)+parray.shape)

# %%
parray.shape
# Out:
# (1, 584, 565, 3)

# %%
count=0
for batch in dg.flow(parray,batch_size=1,save_to_dir='C:\\Users\\archa\\Documents\\colpro1\\set2\\archive\\DRIVE\\training\\1st_manual',save_prefix='40'):
    count+=1
    if count==1:
        break
